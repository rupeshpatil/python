# %%
def lis(arr):
    n = len(arr)
 
    # Declare the list (array) for LIS and initialize LIS
    # values for all indexes
    lis = [1]*n
    print(lis)
 
    # Compute optimized LIS values in bottom up manner
    for i in range (1 , n):
        print("i value", i,arr[i])
        for j in range(0 , i):
            print("J value", j,arr[j])
#             print("Arr of i, j", arr[i], arr[j])
#             print("list of i, j", lis[i], lis[j] + 1)
            if arr[i] > arr[j] and lis[i]< lis[j] + 1 :
                lis[i] = lis[j]+1
                print("if cond", lis)
 
#     # Initialize maximum to 0 to get the maximum of all
#     # LIS
#     maximum = 0
 
#     # Pick maximum of all LIS values
#     for i in range(n):
#         maximum = max(maximum , lis[i])
 
#     return maximum

arr = [10, 22, 9, 33, 21, 50, 41, 60]
print ("Length of lis is", lis(arr))
# Out:
# [1, 1, 1, 1, 1, 1, 1, 1]
# i value 1 22
# J value 0 10
# if cond [1, 2, 1, 1, 1, 1, 1, 1]
# i value 2 9
# J value 0 10
# J value 1 22
# i value 3 33
# J value 0 10
# if cond [1, 2, 1, 2, 1, 1, 1, 1]
# J value 1 22
# if cond [1, 2, 1, 3, 1, 1, 1, 1]
# J value 2 9
# i value 4 21
# J value 0 10
# if cond [1, 2, 1, 3, 2, 1, 1, 1]
# J value 1 22
# J value 2 9
# J value 3 33
# i value 5 50
# J value 0 10
# if cond [1, 2, 1, 3, 2, 2, 1, 1]
# J value 1 22
# if cond [1, 2, 1, 3, 2, 3, 1, 1]
# J value 2 9
# J value 3 33
# if cond [1, 2, 1, 3, 2, 4, 1, 1]
# J value 4 21
# i value 6 41
# J value 0 10
# if cond [1, 2, 1, 3, 2, 4, 2, 1]
# J value 1 22
# if cond [1, 2, 1, 3, 2, 4, 3, 1]
# J value 2 9
# J value 3 33
# if cond [1, 2, 1, 3, 2, 4, 4, 1]
# J value 4 21
# J value 5 50
# i value 7 60
# J value 0 10
# if cond [1, 2, 1, 3, 2, 4, 4, 2]
# J value 1 22
# if cond [1, 2, 1, 3, 2, 4, 4, 3]
# J value 2 9
# J value 3 33
# if cond [1, 2, 1, 3, 2, 4, 4, 4]
# J value 4 21
# J value 5 50
# if cond [1, 2, 1, 3, 2, 4, 4, 5]
# J value 6 41
# Length of lis is None
